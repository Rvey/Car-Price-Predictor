# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
import pickle

# %matplotlib inline
mpl.style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %%
car=pd.read_csv('cotationprice.csv')

# %%
car.head()
# Out:
#      brand    model  year      Energy     gear_box  \
# 0  PEUGEOT     2008  2021  Electrique  Automatique
# 1   NISSAN  Qashqai  2020      Diesel     Manuelle
# 2  RENAULT   Captur  2018     Essence     Manuelle
# 3  RENAULT   Kadjar  2021      Diesel     Manuelle
# 4  PEUGEOT     2008  2018     Essence     Manuelle
#
#                                   Trim     price
# 0                 e-2008 136ch GT Pack  36 890 €
# 1    1.5 dCi 115ch N-Connecta Euro6d-T  21 890 €
# 2  0.9 TCe 90ch energy Business Euro6c  14 999 €
# 3     1.5 Blue dCi 115ch Business - 21  23 780 €
# 4      1.2 PureTech 130ch Crossway S&S  16 490 €

# %%
car.shape
# Out:
# (44399, 7)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44399 entries, 0 to 44398
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   brand     44399 non-null  object
#  1   model     44399 non-null  object
#  2   year      44399 non-null  int64
#  3   Energy    44390 non-null  object
#  4   gear_box  44354 non-null  object
#  5   Trim      44394 non-null  object
#  6   price     44399 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 2.4+ MB

# %% [markdown]
# ##### Check for null values

# %%
car.isnull().sum()
# Out:
# brand        0
# model        0
# year         0
# Energy       9
# gear_box    45
# Trim         5
# price        0
# dtype: int64

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# #### year is an object. Change to integer

# %%
car['year']=car['year'].astype(np.int64)

# %% [markdown]
# #### Check for null values

# %% [markdown]
# #### Price has commas in its prices and is in object

# %%
car['price'] = car['price'].str.replace(r'[^A-Za-z0-9]+', '', regex=True)
car['price'] = car['price'].astype(np.int64)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44399 entries, 0 to 44398
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   brand     44399 non-null  object
#  1   model     44399 non-null  object
#  2   year      44399 non-null  int64
#  3   Energy    44390 non-null  object
#  4   gear_box  44354 non-null  object
#  5   Trim      44394 non-null  object
#  6   price     44399 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 2.4+ MB

# %% [markdown]
# #### gear_box & Trim has nan values

# %%
car=car[~car['gear_box'].isna()]
car=car[~car['Trim'].isna()]

# %%
car.shape
# Out:
# (44349, 7)

# %% [markdown]
# ### check null values

# %%
car.isnull().sum()
# Out:
# brand       0
# model       0
# year        0
# Energy      0
# gear_box    0
# Trim        0
# price       0
# dtype: int64

# %% [markdown]
# #### Resetting the index of the final cleaned data

# %%
car=car.reset_index(drop=True)

# %% [markdown]
# ## Cleaned Data

# %%
car
# Out:
#          brand        model  year      Energy     gear_box  \
# 0      PEUGEOT         2008  2021  Electrique  Automatique
# 1       NISSAN      Qashqai  2020      Diesel     Manuelle
# 2      RENAULT       Captur  2018     Essence     Manuelle
# 3      RENAULT       Kadjar  2021      Diesel     Manuelle
# 4      PEUGEOT         2008  2018     Essence     Manuelle
# ...        ...          ...   ...         ...          ...
# 44344  PEUGEOT          308  2022     Essence     Manuelle
# 44345  CITROËN        JUMPY  2019      Diesel     Manuelle
# 44346  CITROËN           C3  2020     Essence     Manuelle
# 44347     LAND  ROVER RANGE  2016      Diesel     Manuelle
# 44348  PEUGEOT         2008  2016     Essence     Manuelle
#
#                                         Trim  price
# 0                       e-2008 136ch GT Pack  36890
# 1          1.5 dCi 115ch N-Connecta Euro6d-T  21890
# 2        0.9 TCe 90ch energy Business Euro6c  14999
# 3           1.5 Blue dCi 115ch Business - 21  23780
# 4            1.2 PureTech 130ch Crossway S&S  16490
# ...                                      ...    ...
# 44344         PURETECH 130CH S&S BVM6 ALLURE  27800
# 44345    FGN M BLUEHDI 120 S&S BVM6 BUSINESS  20980
# 44346     PURETECH 82 S&S BVM5 FEEL BUSINESS  13980
# 44347  MARK IV ED4 150 2WD E-CAPABILITY PURE  22990
# 44348   1.2 PURETECH 110CH S&S BVM5 CROSSWAY  11990
#
# [44349 rows x 7 columns]

# %%
car.to_csv('Cleaned_Car_data.csv')

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44349 entries, 0 to 44348
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   brand     44349 non-null  object
#  1   model     44349 non-null  object
#  2   year      44349 non-null  int64
#  3   Energy    44349 non-null  object
#  4   gear_box  44349 non-null  object
#  5   Trim      44349 non-null  object
#  6   price     44349 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 2.4+ MB

# %%
car.describe()
# Out:
#                year          price
# count  44349.000000   44349.000000
# mean    2019.905996   28105.186836
# std        1.700049   15196.304152
# min     2009.000000       0.000000
# 25%     2019.000000   17900.000000
# 50%     2020.000000   24900.000000
# 75%     2021.000000   33999.000000
# max     2022.000000  269800.000000

# %%
car.isna().sum()
# Out:
# brand       0
# model       0
# year        0
# Energy      0
# gear_box    0
# Trim        0
# price       0
# dtype: int64

# %%
# car=car[car['price']<6000000]

# %% [markdown]
# ### Checking relationship of Company with Price

# %%
car['brand'].unique()
car['model'].unique()
# Out:
# array(['2008', 'Qashqai', 'Captur', 'Kadjar', 'Clio', '308', 'Megane',
#        '3008', 'C3 Aircross', '208', 'Mini', 'Duster', 'Polo', 'C3',
#        'Twingo', 'C5 Aircross', 'Ds 7 Crossback', 'Corsa', 'Panamera',
#        'C4', 'Serie 1', 'Xceed', '508 Sw', 'Rav4', 'Zoe', 'Kangoo',
#        'Serie 3 Touring', 'Kuga', 'Taigo', 'Corolla', 'A3 Sportback',
#        'Xc40', '718 Cayman', 'Yaris', 'Partner', 'B-Max', 'X4',
#        'Classe E', 'C4 Cactus', 'Kangoo Express', 'Serie 4 Gran Coupe',
#        'Nv300', 'Lodgy', 'Sprinter', 'Classe C Break', '508', 'Niro',
#        'E-Pace', 'Espace', 'Swift', 'Scenic', 'Sandero', 'A4 Avant',
#        'Tiguan Allspace', 'Ceed Sw', 'Discovery Sport', '308 Sw', 'Golf',
#        'Combo Life', 'Stelvio', 'Fiesta', 'Arona', 'Ecosport', 'Leon St',
#        'Glc', 'Talisman', 'X3', 'Ds 3', 'Berlingo Van', 'Talisman Estate',
#        'T-Roc', '108', 'Crossland X', 'Rx', 'Astra Sports Tourer',
#        'Classe A', 'Serie 4 Coupe', 'Grand Scenic', 'Traveller', 'Mokka',
#        'Carens', 'Arkana', 'T-Roc Cabriolet', 'Formentor',
#        'Ds 3 Crossback', 'Serie 7', 'C4 Picasso', 'Grandland X', 'Cx-30',
#        'Xc60', 'Micra', 'Serie 2 Gran Coupe', 'Ranger', 'Juke', 'Puma',
#        'Rifter', 'T-Cross', 'C1', '5008', 'X2', 'Ateca', 'C-Max',
#        'Serie 5 Touring', 'Q5', 'Note', 'Classe C', 'Ignis', 'Nx',
#        'C4 Spacetourer', 'Classe B', 'Cx-5', 'Fabia', 'Cla', 'Ux',
#        'Clubman', 'Serie 2 Active Tourer', 'Master', 'Tiguan', 'Cabrio',
#        'Koleos', 'Serie 2 Coupe', 'X1', 'Touran', 'V90', 'Venga',
#        'Megane Estate', 'C-Hr', 'Aygo', 'Ds 4', 'Glc Coupe',
#        'Grand C4 Spacetourer', 'Classe E Coupe', 'I3', 'Q3', 'Ibiza',
#        'Classe S', 'Jumpy', 'Q2', 'Stonic', 'X6', 'Focus Sw', 'Tipo',
#        'Compass', 'Granturismo', 'Sportage', 'Taycan', 'Eqb',
#        'Tt Roadster', 'Arteon', 'A1 Sportback', 'Levante', '500',
#        'Insignia Sports Tourer', 'Mondeo', 'Expert', 'Transit 2t',
#        'Countryman', 'Classe Cls', 'Gle', 'Cla Shooting Brake', 'Tucson',
#        'Navara', 'Arteon Shooting Brake', '500x', 'Golf Sw', 'Auris',
#        'Clio Estate', 'A6', 'Picanto', 'Transporter', 'Classe E Break',
#        'Serie 3', 'Baleno', 'Trafic', 'Gla', 'California', 'Superb Combi',
#        'C5 X', 'Ds 9', 'V60', 'Express', 'Doblo Cargo', 'Logan Mcv',
#        'Karoq', 'X5', 'Adam', 'Vitara', 'X-Trail', 'Civic', 'Vito',
#        'Fiorino', 'Kamiq', 'Alhambra', 'Serie 5', 'Classe E All-Terrain',
#        'Partner Tepee', 'Transit Custom', 'Citan', 'Xe', 'Tipo Sw',
#        'Yeti', 'Astra', 'Mustang Mach-E', 'Passat Sw', 'Spacetourer',
#        'Galaxy', 'Range Rover Evoque', 'Serie 2 Cabriolet', 'Proace City',
#        'Eqs', 'Berlingo', 'Fortwo Coupe', 'Proace Verso', 'I30 Sw',
#        'Focus', 'Serie 4 Cabriolet', 'Giulietta', 'Mazda2', 'Daily',
#        'Primastar', 'F-Pace', 'E-Tron Gt', 'Ducato', 'Boxer', 'Leon',
#        'S-Max', 'Macan', 'A6 Avant', 'C-Zero', 'Tipo Cross', 'Cayenne',
#        'Trafic Combi', 'Classe C Coupe', 'Octavia Combi', 'Scirocco',
#        'Combo Cargo', 'I20', 'Classe V', 'Q3 Sportback', 'Scudo',
#        'E-Tron Sportback', 'Grand California', 'Scala', 'Serie 8',
#        'Range Rover', 'A3 Berline', 'Serie 2 Gran Tourer', 'Glb',
#        'A5 Sportback', 'Passat', 'V40', 'Up!', 'Mazda6', 'Dokker',
#        'Eclipse Cross', 'Rs4 Avant', 'Range Rover Sport', 'Coccinelle',
#        'Ghibli', 'Q5 Sportback', 'Fortwo Cabriolet', 'Caddy', 'Leaf',
#        'X7', 'Classe E Cabriolet', 'Vivaro', 'Golf Sportsvan',
#        'I20 Active', 'Rs Q3 Sportback', 'Grecale', 'Spring', 'Proace',
#        'Rio', 'Jumper', 'A3 Cabriolet', 'Cherokee', 'Tarraco', 'Ix',
#        'M4 Cabriolet', 'Ceed', 'A8', 'R8', 'Kona', 'Ds 5', 'S3 Sportback',
#        'Panda 4x4', 'Camry', 'Caddy Van', 'Mx-5', 'Xf', 'A1', 'Id.4',
#        'Vivaro Combi', 'Ds 4 Crossback', 'Insignia Grand Sport',
#        'Classe A Berline', 'Xv', 'Leon X-Perience', 'Serie 8 Gran Coupe',
#        'Edge', 'Mondeo Sw', 'F-Type Coupe', 'Cx-3', 'Jimny', 'Sharan',
#        'Qx70', 'C2', 'I20 Coupe', 'Kangoo Van', 'A1 Citycarver', 'Id.3',
#        'C3 Picasso', 'Ehs', 'I30', 'Classe Ml', 'Movano', 'Verso',
#        'V60 Cross Country', 'Jogger', 'V90 Cross Country', 'Renegade',
#        'Corolla Touring Sports', 'Panda', 'Lc', 'Focus Active Sw',
#        'Model X', 'Mazda3', 'Range Rover Velar', 'Classe C All-Terrain',
#        'Mustang Fastback', 'Grandland', 'I4', 'Marco Polo', '500c',
#        'I-Pace', 'Octavia', 'Amarok', 'Pro Ceed', 'Coupe', 'Classe Glk',
#        'Touareg', 'Meriva', 'Crafter', 'Slc', 'Grand C4 Picasso',
#        'Paceman', 'Across', 'Defender', 'Ioniq', 'Z4 Roadster',
#        'S1 Sportback', 'M4 Coupe', 'Adam Rocks', 'Rcz', 'Forfour', 'Cr-V',
#        'Sorento', 'Multivan', 'Superb', 'A3', 'D-Max', 'Q8', 'Space Star',
#        'Ds 3 Cabrio', 'Grand C-Max', 'Nemo', 'Q7', 'Discovery', 'Pulsar',
#        'Mokka X', 'Outlander', 'Golf Plus', '206+', '911 Coupe', 'Rs5',
#        'Megane Cc', 'A110', 'A5', 'Karl', 'Np300 Navara', 'A4', 'Nv200',
#        '500l', 'Forester', 'Zafira', 'Classe C Cabriolet',
#        '911 Cabriolet', 'Pajero', 'Townstar Combi', 'Gle Coupe', 'Rs Q3',
#        'Focus Active', 'Altea', '500l Living',
#        'Prius Hybride Rechargeable', 'R8 Spyder', 'Swace',
#        'Serie 3 Gran Turismo', 'Rc', 'Freelander', '508 Hybrid4', 'Id.5',
#        'Megane Coupe', 'Tt', 'L200', 'Fabia Combi', 'Ct', 'Q30',
#        'Proace City Verso', 'Modus', 'Xc90', '207', 'Sq7', 'C-Elysee',
#        'Eqc', 'Is', 'Serie 6 Gran Turismo', 'C4 Aircross',
#        'Transit Connect', 'M3', 'Jazz', 'Caddy Cargo', '718 Boxster',
#        'Classe X', 'A4 Allroad', 'Range Rover Evoque Cabriolet',
#        'V40 Cross Country', 'Kodiaq', 'Alaskan', 'Twizy', 'Ka+ Active',
#        'Karl Rocks', 'Cayenne Coupe', 'Serie 3 Cabriolet', 'S3',
#        'A6 Allroad', 'Classe T', '370z', 'Hr-V', 'X6 M', 'Ix3',
#        'Tivoli Xlv', 'Transit Courier', '107', 'Grand Tourneo Connect',
#        'Fiesta Active', 'Ka+', 'Spark', 'Xj', 'Ds', 'Logan', 'Gladiator',
#        'Sq5', 'Grand Kangoo', 'A5 Cabriolet', 'Punto', '207 Cc', 'Eqa',
#        'Fullback', 'Prius', 'Ion', 'Tonale', 'Serie 2', 'Giulia', 'S4',
#        'Up', 'Ducato Benne', 'Wrangler', 'S60', 'Classe Glc', 'Bayon',
#        'Insignia', 'S5', 'Ds 7', 'Serie 4', 'Explorer', 'Ix20', 'E-Tron',
#        'Quattroporte', 'Q4 E-Tron', 'Doblo', 'I10', 'Fortwo', 'Transit',
#        'Combo', 'A7', 'Express Van', 'Soul', 'E-Ulysse', 'S7', 'Cx5',
#        'Tivoli', 'California T', 'Talento', 'F-Type', 'M440i', 'Hilux',
#        'Viano', 'Sx4', 'C5', 'Santa Fe', 'Mustang', 'S-Cross', '911',
#        'Rodius', 'Rs3', 'Gr Supra', 'Mx5', 'Mx-30', 'Tts', 'Mg5',
#        'Land Cruiser', 'Rs4', 'Nv 250', 'Highlander', 'S90', 'Born',
#        'Cx3', 'Classe G', 'Asx', 'Sl', 'Zoé', 'Marvel R', 'Zs', 'Amg Gt',
#        'Eqe', 'Tourneo Connect', 'Ev6', 'Celerio', 'Levorg', 'Rc F',
#        'Enyaq', 'Honda E', 'Ls', 'Caravelle', 'Ka', 'Model 3', 'Es',
#        'Optima', 'Serie 6', '718', 'Mito', 'Grand Cherokee', 'Fuso',
#        'CLIO', 'COMBO', 'SCUDO', 'C5 AIRCROSS', 'C3 AIRCROSS', 'TWINGO',
#        'PARTNER', 'GOLF', '3 CROSSBACK', 'NEMO', 'ECOSPORT',
#        '7 CROSSBACK', 'C4 CACTUS', 'GRANDLAND', 'SANDERO', 'TOUAREG',
#        'YARIS', 'CLA', 'KUGA', 'CLASSE C', 'T-ROC', 'QASHQAI', 'CLASSE B',
#        'VENGA', '4', 'PANDA', 'C4 GRAND', 'CORSA', 'C4 PICASSO', 'KANGOO',
#        'FORFOUR', 'TALISMAN', '308 SW', 'RIFTER', '508 SW', 'BOXER',
#        'JUMPER', 'CROSSLAND', 'TIGUAN', 'DUSTER', 'MEGANE', 'FABIA',
#        'POLO', 'JUMPY', 'CLASSE A', '500L', 'BERLINGO', 'SCENIC', 'ASTRA',
#        'CAPTUR', 'SERIE 1', 'KADJAR', 'MOKKA', 'ARONA', 'ONE',
#        'SPACETOURER', 'TRAFIC', 'JUKE', 'EXPERT', 'LODGY', 'ADAM',
#        'MERIVA', 'RCZ', '500X', 'IBIZA', 'DOBLO', 'MOVANO', 'C-ZERO',
#        'SERIE 3', 'MODEL 3', 'ARKANA', 'FIESTA', 'JIMNY', 'SUPERB',
#        'KAROK', 'ROMEO GIULIA', 'TOURAN', 'C3 PICASSO', 'B-MAX',
#        'SPRINTER', 'T-CROSS', '3', '9', 'AVENSIS', 'F-PACE', 'NX',
#        'INSIGNIA', 'SERIE 2', 'LEON', 'ROMEO STELVIO', 'VITARA', 'ANTARA',
#        'COMPASS', 'FOCUS', 'AYGO', 'STONIC', 'VITO', 'TUCSON', 'ION',
#        'XC40', '595', 'SPORTAGE', 'GLE', 'C-MAX', 'ESPACE', 'SHARAN',
#        'PASSAT', 'PUMA', 'SCIROCCO', 'NP300', 'KOLEOS', 'ZOE', 'NV300',
#        'MACAN', 'E-PACE', 'KODIAQ', 'RENEGADE', 'GLA', 'BALENO', 'SWIFT',
#        'DAILY', 'CAYENNE', 'CALIFORNIA', 'TRANSPORTER', 'EDGE', 'PROACE',
#        'XE', 'EXPRESS VAN', 'MONDEO', 'MASTER', 'SCALA', 'LEAF',
#        'C4 SPACETOURER', 'TRANSIT', 'KONA', 'RANGER', 'BIPPER',
#        'CLASSE M', '4 CROSSBACK', 'TIPO', 'GLC', 'ATECA', 'ARTEON',
#        'NEW BEETLE', 'CX-3', 'MARCO POLO', 'ROVER RANGE', 'OCTAVIA',
#        'PICANTO', 'KAMIQ', 'CHEROKEE', 'CIVIC', 'EHS', 'SQ5',
#        'COUNTRYMAN', 'CLASSE E', 'C4 AIRCROSS', 'CABRIO', 'CR-V',
#        'SERIE 5', 'C-HR', 'EOS', 'TRAVELLER', 'MICRA', 'Z4', 'GLADIATOR',
#        'CLUBMAN', 'FORMENTOR', 'SPACE STAR', 'XC60', 'X-TRAIL', 'XCEED',
#        'DUCATO', '5', 'AURIS', 'ROMEO TONALE', 'ZAFIRA TOURER',
#        'CLASSE V', 'SERIE 4', 'WRANGLER', 'FORTWO', 'ZS', 'RIO', 'C30',
#        'E-MEHARI', 'KARL', 'IX20', 'SANTA FE', '308 CC',
#        'ROVER DISCOVERY', 'DOKKER', 'CADDY', 'ROMEO MITO', 'IGNIS', '2',
#        'TT', 'IX35', 'HILUX', 'PARTNER TEPEE', 'SERIE 7', 'SX4',
#        '3 CABRIO', 'COROLLA', 'ROMEO GIULIETTA', 'JAZZ', 'KA', 'S-MAX',
#        'S-CROSS', 'NIRO', 'ZAFIRA LIFE', 'SPRING', 'XV', 'OUTLANDER',
#        'TIGUAN ALLSPACE', 'CELERIO', 'RX'], dtype=object)

# %%
plt.subplots(figsize=(15,7))
ax=sns.boxplot(x='brand',y='price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()

# %% [markdown]
# ### Checking relationship of Year with Price

# %%
# plt.subplots(figsize=(20,10))
# ax=sns.swarmplot(x='year',y='price',data=car)
# ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
# plt.show()

# %% [markdown]
# ### Checking relationship of gear_box with Price

# %%
# sns.relplot(x='gear_box',y='price',data=car,height=7,aspect=1.5)

# %%
# plt.subplots(figsize=(14,7))
# sns.boxplot(x='gear_box',y='price',data=car)

# %% [markdown]
# ### Relationship of Price with FuelType, Year and Company mixed

# %%
# ax=sns.relplot(x='brand',y='price',data=car,hue='gear_box',size='year',height=7,aspect=2)
# ax.set_xticklabels(rotation=40,ha='right')

# %% [markdown]
# ### Extracting Training Data

# %%
X=car[['model','brand','gear_box']]
y=car['price']

# %%
X
# Out:
#              model    brand     gear_box
# 0             2008  PEUGEOT  Automatique
# 1          Qashqai   NISSAN     Manuelle
# 2           Captur  RENAULT     Manuelle
# 3           Kadjar  RENAULT     Manuelle
# 4             2008  PEUGEOT     Manuelle
# ...            ...      ...          ...
# 44344          308  PEUGEOT     Manuelle
# 44345        JUMPY  CITROËN     Manuelle
# 44346           C3  CITROËN     Manuelle
# 44347  ROVER RANGE     LAND     Manuelle
# 44348         2008  PEUGEOT     Manuelle
#
# [44349 rows x 3 columns]

# %%
y.shape
# Out:
# (44349,)

# %% [markdown]
# ### Applying Train Test Split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %% [markdown]
# #### Creating an OneHotEncoder object to contain all the possible categories

# %%
ohe=OneHotEncoder()
ohe.fit(X[['model','brand','gear_box']])
# Out:
# OneHotEncoder()

# %% [markdown]
# #### Creating a column transformer to transform categorical columns

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['model','brand','gear_box']),
                                    remainder='passthrough')
column_trans
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('onehotencoder',
#                                  OneHotEncoder(categories=[array(['107', '108', '2', '2008', '206+', '207', '207 Cc', '208', '3',
#        '3 CABRIO', '3 CROSSBACK', '3008', '308', '308 CC', '308 SW',
#        '308 Sw', '370z', '4', '4 CROSSBACK', '5', '500', '5008', '500L',
#        '500X', '500c', '500l', '500l Living', '500x', '508',
#        '508 Hybrid4', '508 SW', '508 Sw', '595',...
#        'JEEP', 'KIA', 'LAND', 'LAND ROVER', 'LAND-ROVER', 'LEXUS',
#        'MASERATI', 'MAZDA', 'MERCEDES', 'MG', 'MINI', 'MITSUBISHI',
#        'NISSAN', 'OPEL', 'PEUGEOT', 'PORSCHE', 'RENAULT', 'SEAT', 'SKODA',
#        'SMART', 'SSANGYONG', 'SUBARU', 'SUZUKI', 'TESLA', 'TOYOTA',
#        'VOLKSWAGEN', 'VOLVO'], dtype=object),
#                                                            array(['Automatique', 'Manuelle', 'Robotisée'], dtype=object)]),
#                                  ['model', 'brand', 'gear_box'])])

# %% [markdown]
# #### Linear Regression Model

# %%
lr=LinearRegression()

# %% [markdown]
# #### Making a pipeline

# %%
pipe=make_pipeline(column_trans,lr)

# %% [markdown]
# #### Fitting the  model

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['107', '108', '2', '2008', '206+', '207', '207 Cc', '208', '3',
#        '3 CABRIO', '3 CROSSBACK', '3008', '308', '308 CC', '308 SW',
#        '308 Sw', '370z', '4', '4 CROSSBACK', '5', '500', '5008', '500L',
#        '500X', '500c', '500l', '500l Living', '500x', '508...
#        'JEEP', 'KIA', 'LAND', 'LAND ROVER', 'LAND-ROVER', 'LEXUS',
#        'MASERATI', 'MAZDA', 'MERCEDES', 'MG', 'MINI', 'MITSUBISHI',
#        'NISSAN', 'OPEL', 'PEUGEOT', 'PORSCHE', 'RENAULT', 'SEAT', 'SKODA',
#        'SMART', 'SSANGYONG', 'SUBARU', 'SUZUKI', 'TESLA', 'TOYOTA',
#        'VOLKSWAGEN', 'VOLVO'], dtype=object),
#                                                                             array(['Automatique', 'Manuelle', 'Robotisée'], dtype=object)]),
#                                                   ['model', 'brand',
#                                                    'gear_box'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred=pipe.predict(X_test)

# %% [markdown]
# #### Checking R2 Score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7485958420171805

# %% [markdown]
# #### Finding the model with a random state of TrainTestSplit where the model was found to give almost 0.92 as r2_score

# %%
scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 7

# %%
scores[np.argmax(scores)]
# Out:
# 0.7875447543062843

# %%
pipe.predict(pd.DataFrame(columns=X_test.columns,data=np.array(['Qashqai','NISSAN','Automatique']).reshape(1,3)))
# Out:
# array([30202.35972949])

# %% [markdown]
# #### The best model is found at a certain random state

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.7875447543062843

# %%
pickle.dump(pipe,open('CarPricePredict.pkl','wb'))

# %%
pipe.predict(pd.DataFrame(columns=['model','brand','gear_box'],data=np.array(['Qashqai','NISSAN','Automatique']).reshape(1,3)))
# Out:
# array([29935.99122775])

# %%
pipe.predict(pd.DataFrame(columns=['model','brand','gear_box'],data=np.array(['Qashqai','NISSAN','Automatique']).reshape(1,3)))
# Out:
# array([29935.99122775])
